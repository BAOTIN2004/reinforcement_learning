# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

# %%
x=0
y=0

# %%
n=100
l=[]
a=[1,-1]
for i in range(n):
    b=np.random.choice(a)
    x+=b
    l.append(x)

plt.step(np.arange(len(l)),l)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
n=100
L=[]
a=[1,-1]
for i in range(n):
   b =  2*sp.stats.bernoulli.rvs(p=0.5) - 1
   x+=b
   L.append(x)
   if x == 0 or x==100:
    break

plt.step(np.arange(len(L)),L)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
p=np.matrix([[0.8,0.2],[0.3,0.7]])
p
# Out:
# matrix([[0.8, 0.2],
#         [0.3, 0.7]])

# %%
p0=np.array([1,0])
rv=[]
rb=[]
rs=[]
for i in range(1,31):
    Pi=p**i
    pi=Pi.T@p0
    rv.append(pi[0,0])
    rb.append(pi[0,1])

plt.plot(rv,'o--',label='Vui')
plt.plot(rb,'*--',label='buồn')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
